# %%
# %pylab inline
import fpfs
import matplotlib.pylab as plt
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
cat = fpfs.simutil.read_cosmos_catalog()

# %%
cat1 = cat[~cat["use_bulgefit"].astype(bool)]
plt.hist(np.log10(cat1['hlr'][:,0]), range=(-2,1.0))
# Out:
# (array([9.0000e+01, 6.1000e+02, 3.1300e+03, 1.4763e+04, 2.4745e+04,
#         1.2213e+04, 2.3100e+03, 1.8600e+02, 3.0000e+00, 0.0000e+00]),
#  array([-2. , -1.7, -1.4, -1.1, -0.8, -0.5, -0.2,  0.1,  0.4,  0.7,  1. ]),
#  <BarContainer object of 10 artists>)

# %%
cat2 = cat[cat["use_bulgefit"].astype(bool)]
plt.hist(np.log10(cat2['hlr'][:,1]), range=(-2,1))
# Out:
# (array([ 714., 3007., 6999., 6920., 3885., 1453.,  267.,   17.,    0.,
#            0.]),
#  array([-2. , -1.7, -1.4, -1.1, -0.8, -0.5, -0.2,  0.1,  0.4,  0.7,  1. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(np.log10(cat2["hlr"][:, 2]), range=(-2,1))
# Out:
# (array([  97.,  444., 1196., 4802., 8775., 6024., 1810.,  245.,   14.,
#            0.]),
#  array([-2. , -1.7, -1.4, -1.1, -0.8, -0.5, -0.2,  0.1,  0.4,  0.7,  1. ]),
#  <BarContainer object of 10 artists>)

# %%
import galsim
bb = galsim.BoundsI(0, 10, 0, 10)

# %%
bb.getXMin()
# Out:
# 0

# %%
bb.getXMax()
# Out:
# 10

# %%
10**((27-26)/2.5)/0.26
# Out:
# 9.66110165965223

# %%
10**((27-25)/2.5)/0.26
# Out:
# 24.267590172315128
