# %%
# %pylab inline
import gc
import fpfs
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Do not have lsst pipeline!

# %%
import math
math.factorial
# Out:
# <function math.factorial(x, /)>

# %%
a=np.random.randn(28,28)
b1=fpfs.imgutil.getFouPow(a)
b2=fpfs.imgutil.getFouPow_new(a)

# %%
np.max(np.abs(b1-b2))
# Out:
# 1.8189894035458565e-12

# %%
plt.imshow((b1-b2)[:,:])
plt.colorbar()

# %%
# %%time
for i in range(10000):
    a=np.random.randn(128,128)
    fpfs.imgutil.getFouPow_new(a)
# Out:
# CPU times: user 11.4 s, sys: 1.77 ms, total: 11.4 s
# Wall time: 11.4 s

# %%
# %%time
for i in range(10000):
    a=np.random.randn(128,128)
    fpfs.imgutil.getFouPow(a)
# Out:
# CPU times: user 14.5 s, sys: 1.24 ms, total: 14.5 s
# Wall time: 14.5 s

# %%
a=np.meshgrid(np.arange(64),np.arange(64))[0]

# %%
imshow(a)

# %%
imshow(np.fliplr(a))

# %%
imshow(b1)

# %%
imshow(b2)
